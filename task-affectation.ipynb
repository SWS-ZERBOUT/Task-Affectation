# %%
import pandas as pd

# %%
df = pd.read_excel("Competences_ORS (réponses).xlsx")

# %%
df.drop('Horodateur', inplace=True, axis=1)

# %%
df
# Out:
#                   Full Name  \
# 0    BOUKHALFA Mohamed Anis
# 1             djihane saidi
# 2      kenai houssem eddine
# 3            Guerni Yousra
# 4             Hazem Brahimi
# 5               Lassal ania
# 6        BENABDALLAH Billel
# 7            Neufel kessar
# 8          Skender Abdallah
# 9              ADNANE Ayoub
# 10  Amanzougaghene Thanina
# 11           Babouri sirine
# 12           Camelia Abouhi
# 13       SOFIA BENDIFALLAH
# 14           Akila Bouazza
#
#                                           Your skills  \
# 0   Web Dev, Design, Data Science, Video Editing, ...
# 1   Web Dev, Data Science, Public Speaking, Progra...
# 2                                              Design
# 3                         Communication, Organization
# 4                           Data Science, Programming
# 5        Communication, Public Speaking, Organization
# 6                        Web Dev, Design, Programming
# 7   Video Editing, Photography, Social Media, Comm...
# ...

# %%
df[df['Your skills'].str.contains('Web Dev')]
# Out:
#                 Full Name                                        Your skills  \
# 0  BOUKHALFA Mohamed Anis  Web Dev, Design, Data Science, Video Editing, ...
# 1           djihane saidi  Web Dev, Data Science, Public Speaking, Progra...
# 6      BENABDALLAH Billel                       Web Dev, Design, Programming
#
#               Explain what you can do  \
# 0                               kolch
# 1  The project. Help in organization
# 6
#
#   Show us an example of your work if you can
# 0                                        NaN
# 1                                        NaN
# 6                                        NaN
